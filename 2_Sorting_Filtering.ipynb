# %% [markdown]
# <a href="https://colab.research.google.com/github/xc308/Python_Data_Analysis/blob/main/2_Sorting_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# 2016-FCC-New-Coders-Survey-Data.csv  sample_data

# %%
import pandas as pd

df = pd.read_csv("2016-FCC-New-Coders-Survey-Data.csv")
# Out:
# <ipython-input-2-1355c6acc8f2>:3: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("2016-FCC-New-Coders-Survey-Data.csv")

# %%
df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
df.dtypes
# Out:
# Age                     float64
# AttendedBootcamp        float64
# BootcampFinish          float64
# BootcampFullJobAfter    float64
# BootcampLoanYesNo       float64
#                          ...
# ResourceW3Schools       float64
# ResourceYouTube         float64
# SchoolDegree             object
# SchoolMajor              object
# StudentDebtOwe          float64
# Length: 113, dtype: object

# %%
df_sub = df[["Age", "Gender", "ChildrenNumber", "CountryOfResidence", "LanguageAtHome", "HoursSpentLearningToCode",
    "Income", "StudentDebtOwe", "IsSoftwareDev", "MaritalStatus", "MoneySpentLearningToCode", "MonthsSpentProgramming",
    "YearsSpentLearningToCode", "LearningViaBooks", "LearningViaCoursera"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-218fde27e12f> in <cell line: 0>()
# ----> 1 df_sub = df[["Age", "Gender", "NumberOfChildren", "CountryOfResidence", "LanguageAtHome", "HoursSpentLearningToCode",
#       2     "Income", "StudentDebtOwe", "IsSoftwareDev", "MaritalStatus", "MoneySpentLearningToCode", "MonthsSpentProgramming",
#       3     "YearsSpentLearningToCode", "LearningViaBooks", "LearningViaCoursera"]]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15620 entries, 0 to 15619
# Columns: 113 entries, Age to StudentDebtOwe
# dtypes: float64(85), object(28)
# memory usage: 13.5+ MB

# %%
## attributes

df.columns
df.dtypes

## methods
df.info()

# %%
cols = ['ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse']
df_sub = df[cols]
# Out:
# ResourceSoloLearn        float64
# ResourceStackOverflow    float64
# ResourceTreehouse        float64
# dtype: object

# %%
type(df_sub) # pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
age = df["Age"]
type(age) # pandas.core.series.Series
# Out:
# pandas.core.series.Series

# %%
age.count() # return the number of non-missing (non-NaN) values in each column.
# Out:
# np.int64(13613)

# %%
len(age) # include NA values
# Out:
# 15620

# %%
df.count() # non-NULL value for each column
# Out:
# Age                     13613
# AttendedBootcamp        15380
# BootcampFinish            933
# BootcampFullJobAfter      635
# BootcampLoanYesNo         934
#                         ...
# ResourceW3Schools         121
# ResourceYouTube           121
# SchoolDegree            13679
# SchoolMajor              8450
# StudentDebtOwe           3438
# Length: 113, dtype: int64

# %% [markdown]
# ## Dictionary

# %%
library_income = {
    'Avon': 685678,
    'Central': 1234567,
    'Westside': 987654
}

keys = library_income.keys()
print(keys)


for key in library_income.keys():
    print(f"{key} made {library_income[key]} in 1996.")
# Out:
# dict_keys(['Avon', 'Central', 'Westside'])
# Avon made 685678 in 1996.
# Central made 1234567 in 1996.
# Westside made 987654 in 1996.

# %%
##NumPy Arrays

# %%
import numpy as np

# create a numpy array
array = np.array([1, 2, 3, 4])

# accesing elements
print(array[0])

# vectorization add, apply an operation to all elements in the array simultaneously
print(array + 10)
# Out:
# 1
# [11 12 13 14]

# %%
# Transforming a list to a NumPy array
x_list = [10, 20, 30, 40]
x_array = np.array(x_list)
print(x_array) # Output: [10 20 30 40]
# Out:
# [10 20 30 40]

# %% [markdown]
# ## Sort

# %%
df.sort_values(by = "Age")
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 7341   10.0               0.0             NaN                   NaN
# 7419   10.0               0.0             NaN                   NaN
# 1594   11.0               0.0             NaN                   NaN
# 3170   11.0               0.0             NaN                   NaN
# 1858   11.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 14981   NaN               0.0             NaN                   NaN
# 15058   NaN               0.0             NaN                   NaN
# 15158   NaN               0.0             NaN                   NaN
# 15184   NaN               0.0             NaN                   NaN
# 15351   NaN               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# ...

# %%
df_sort_age = df.sort_values(by = "Age")
type(df_sort_age) # pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df_sort_age_desc = df.sort_values(by = "Age", ascending = False)
df_sort_age_desc.head()
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 5554  86.0               NaN             NaN                   NaN
# 560   80.0               0.0             NaN                   NaN
# 1846  75.0               0.0             NaN                   NaN
# 3927  75.0               0.0             NaN                   NaN
# 450   75.0               0.0             NaN                   NaN
#
#       BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 5554                NaN                NaN          NaN                 NaN
# 560                 NaN                NaN          NaN                 NaN
# 1846                NaN                NaN          NaN                 NaN
# 3927                NaN                NaN          NaN                 NaN
# 450                 NaN                NaN          NaN                 NaN
#
#       BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# ...

# %% [markdown]
# ## Sorting by multiple columns

# %%
by_cols = ["Age", "ChildrenNumber"]
order = [False, False]

df_sort_multiple = df.sort_values(by = by_cols, ascending = order)
df_sort_multiple.head()
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 5554  86.0               NaN             NaN                   NaN
# 560   80.0               0.0             NaN                   NaN
# 450   75.0               0.0             NaN                   NaN
# 1846  75.0               0.0             NaN                   NaN
# 3927  75.0               0.0             NaN                   NaN
#
#       BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 5554                NaN                NaN          NaN                 NaN
# 560                 NaN                NaN          NaN                 NaN
# 450                 NaN                NaN          NaN                 NaN
# 1846                NaN                NaN          NaN                 NaN
# 3927                NaN                NaN          NaN                 NaN
#
#       BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# ...

# %% [markdown]
# ## Filter

# %%
df_English = df[df["SchoolMajor"] == "English"]
print(df_English.head())
# Out:
#       Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 5    34.0               0.0             NaN                   NaN
# 30   33.0               0.0             NaN                   NaN
# 55   30.0               0.0             NaN                   NaN
# 137  40.0               0.0             NaN                   NaN
# 191  31.0               0.0             NaN                   NaN
#
#      BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 5                  NaN                NaN          NaN                 NaN
# 30                 NaN                NaN          NaN                 NaN
# 55                 NaN                NaN          NaN                 NaN
# 137                NaN                NaN          NaN                 NaN
# 191                NaN                NaN          NaN                 NaN
#
#      BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# ...

# %%
type(df_English) # pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df_abv_30 = df[df["Age"] > 30]
df_abv_30.head()
# Out:
#      Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 5   34.0               0.0             NaN                   NaN
# 7   35.0               0.0             NaN                   NaN
# 8   33.0               0.0             NaN                   NaN
# 9   33.0               0.0             NaN                   NaN
# 10  57.0               0.0             NaN                   NaN
#
#     BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 5                 NaN                NaN          NaN                 NaN
# 7                 NaN                NaN          NaN                 NaN
# 8                 NaN                NaN          NaN                 NaN
# 9                 NaN                NaN          NaN                 NaN
# 10                NaN                NaN          NaN                 NaN
#
#     BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 5                 NaN             NaN  ...               NaN
# ...

# %%
df_abv_30["Age"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Filtering by multiple conditions

# %%
df_abv30_Cpt = df[(df["Age"] > 30) & (df["SchoolMajor"] == "Computer Science")]
df_abv30_Cpt.head()
# Out:
#       Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 10   57.0               0.0             NaN                   NaN
# 103  35.0               0.0             NaN                   NaN
# 192  50.0               0.0             NaN                   NaN
# 240  33.0               0.0             NaN                   NaN
# 258  50.0               0.0             NaN                   NaN
#
#      BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 10                 NaN                NaN          NaN                 NaN
# 103                NaN                NaN          NaN                 NaN
# 192                NaN                NaN          NaN                 NaN
# 240                NaN                NaN          NaN                 NaN
# 258                NaN                NaN          NaN                 NaN
#
#      BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# ...

# %%
df_abv30_or_cmpt = df[(df["Age"] > 30) | (df["SchoolMajor"] == "ComputerScience")]
df_abv30_or_cmpt.head()
# Out:
#      Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 5   34.0               0.0             NaN                   NaN
# 7   35.0               0.0             NaN                   NaN
# 8   33.0               0.0             NaN                   NaN
# 9   33.0               0.0             NaN                   NaN
# 10  57.0               0.0             NaN                   NaN
#
#     BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 5                 NaN                NaN          NaN                 NaN
# 7                 NaN                NaN          NaN                 NaN
# 8                 NaN                NaN          NaN                 NaN
# 9                 NaN                NaN          NaN                 NaN
# 10                NaN                NaN          NaN                 NaN
#
#     BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 5                 NaN             NaN  ...               NaN
# ...

# %%
df_idx_age = df.set_index("Age")
df_idx_age.head()
# Out:
#       AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# Age
# 28.0               0.0             NaN                   NaN
# 22.0               0.0             NaN                   NaN
# 19.0               0.0             NaN                   NaN
# 26.0               0.0             NaN                   NaN
# 20.0               0.0             NaN                   NaN
#
#       BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# Age
# 28.0                NaN                NaN          NaN                 NaN
# 22.0                NaN                NaN          NaN                 NaN
# 19.0                NaN                NaN          NaN                 NaN
# 26.0                NaN                NaN          NaN                 NaN
# 20.0                NaN                NaN          NaN                 NaN
#
#       BootcampRecommend  ChildrenNumber                 CityPopulation  ...  \
# ...

# %%
# then access data using nex index via function .loc
df_idx_age.loc[28]
# Out:
#       AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# Age
# 28.0               0.0             NaN                   NaN
# 28.0               0.0             NaN                   NaN
# 28.0               0.0             NaN                   NaN
# 28.0               0.0             NaN                   NaN
# 28.0               0.0             NaN                   NaN
# ...                ...             ...                   ...
# 28.0               1.0             1.0                   1.0
# 28.0               0.0             NaN                   NaN
# 28.0               0.0             NaN                   NaN
# 28.0               0.0             NaN                   NaN
# 28.0               0.0             NaN                   NaN
#
#       BootcampLoanYesNo  BootcampMonthsAgo           BootcampName  \
# Age
# 28.0                NaN                NaN                    NaN
# 28.0                NaN                NaN                    NaN
# ...

# %%
## or use iloc to select the rows base on the data in the data frame

df_idx_age.iloc[28]
# Out:
# AttendedBootcamp                           0.0
# BootcampFinish                             NaN
# BootcampFullJobAfter                       NaN
# BootcampLoanYesNo                          NaN
# BootcampMonthsAgo                          NaN
#                                  ...
# ResourceW3Schools                          NaN
# ResourceYouTube                            NaN
# SchoolDegree                 bachelor's degree
# SchoolMajor             Information Technology
# StudentDebtOwe                             NaN
# Name: 34.0, Length: 112, dtype: object

# %%
df_idx_age.iloc[0:28] # 28th row not included
# Out:
#       AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# Age
# 28.0               0.0             NaN                   NaN
# 22.0               0.0             NaN                   NaN
# 19.0               0.0             NaN                   NaN
# 26.0               0.0             NaN                   NaN
# 20.0               0.0             NaN                   NaN
# 34.0               0.0             NaN                   NaN
# 23.0               0.0             NaN                   NaN
# 35.0               0.0             NaN                   NaN
# 33.0               0.0             NaN                   NaN
# 33.0               0.0             NaN                   NaN
# 57.0               0.0             NaN                   NaN
# 23.0               0.0             NaN                   NaN
# 47.0               0.0             NaN                   NaN
# NaN                0.0             NaN                   NaN
# ...

# %% [markdown]
# ## Select both row and columns for speed using "at"
#
# ### select row 2 and column "A"
# ### value = df.at[2, "A"]
# # to retrive a single value fast

# %%
df.at[2, "Age"]
# Out:
# np.float64(19.0)

# %%
## Select data based on labels

### loc method is label-based, allowing you to select data by row and column labels

# %%
# To select rows where the "Age" column is greater than 30

df.loc[df["Age"] > 30].head()
# Out:
#      Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 5   34.0               0.0             NaN                   NaN
# 7   35.0               0.0             NaN                   NaN
# 8   33.0               0.0             NaN                   NaN
# 9   33.0               0.0             NaN                   NaN
# 10  57.0               0.0             NaN                   NaN
#
#     BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 5                 NaN                NaN          NaN                 NaN
# 7                 NaN                NaN          NaN                 NaN
# 8                 NaN                NaN          NaN                 NaN
# 9                 NaN                NaN          NaN                 NaN
# 10                NaN                NaN          NaN                 NaN
#
#     BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 5                 NaN             NaN  ...               NaN
# ...

# %%
## To select rows 0 to 3 and columns "Age" and "Gender"

df.loc[0:3, ["Age", "Gender"]]
# Out:
#     Age  Gender
# 0  28.0    male
# 1  22.0    male
# 2  19.0    male
# 3  26.0  female

# %% [markdown]
# ## iloc
#
# ## integer-based, allowing you to select data by row and column indices
#
# ## o select the first three rows and the first two columns,
#
# df.iloc[0:3, 0:2]

# %%
df.iloc[0:3, 1:5]
# Out:
#    AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  BootcampLoanYesNo
# 0               0.0             NaN                   NaN                NaN
# 1               0.0             NaN                   NaN                NaN
# 2               0.0             NaN                   NaN                NaN

# %%
df.iloc[0:8, 2:9]
# Out:
#    BootcampFinish  BootcampFullJobAfter  BootcampLoanYesNo  BootcampMonthsAgo  \
# 0             NaN                   NaN                NaN                NaN
# 1             NaN                   NaN                NaN                NaN
# 2             NaN                   NaN                NaN                NaN
# 3             NaN                   NaN                NaN                NaN
# 4             NaN                   NaN                NaN                NaN
# 5             NaN                   NaN                NaN                NaN
# 6             NaN                   NaN                NaN                NaN
# 7             NaN                   NaN                NaN                NaN
#
#   BootcampName  BootcampPostSalary  BootcampRecommend
# 0          NaN                 NaN                NaN
# 1          NaN                 NaN                NaN
# 2          NaN                 NaN                NaN
# ...

# %% [markdown]
# ## query
#
# ###  query method allows you to query a DataFrame using a string expression
#
# a convenient way to filter data based on conditions

# %%
df.query("Age > 30").head()
# Out:
#      Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 5   34.0               0.0             NaN                   NaN
# 7   35.0               0.0             NaN                   NaN
# 8   33.0               0.0             NaN                   NaN
# 9   33.0               0.0             NaN                   NaN
# 10  57.0               0.0             NaN                   NaN
#
#     BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 5                 NaN                NaN          NaN                 NaN
# 7                 NaN                NaN          NaN                 NaN
# 8                 NaN                NaN          NaN                 NaN
# 9                 NaN                NaN          NaN                 NaN
# 10                NaN                NaN          NaN                 NaN
#
#     BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 5                 NaN             NaN  ...               NaN
# ...

# %% [markdown]
# ## Buenos Aires Subway

# %%
df= pd.read_csv("BaseUnificadaEstaciones.csv")

# %%
df.head()
# Out:
#       FECHA ESTACION LINEA DESDE  HORA  CANTIDAD
# 0  3/1/2020   Acoyte     A  7:45   7.0      20.0
# 1  3/1/2020   Acoyte     A  8:00   8.0      16.0
# 2  3/1/2020   Acoyte     A  8:15   8.0      22.0
# 3  3/1/2020   Acoyte     A  8:30   8.0      27.0
# 4  3/1/2020   Acoyte     A  8:45   8.0      37.0

# %%
df.columns = ['date', 'station', 'line', 'from', 'hour', 'pax_TOTAL']

# %%
df.head()
# Out:
#        date station line  from  hour  pax_TOTAL
# 0  3/1/2020  Acoyte    A  7:45   7.0       20.0
# 1  3/1/2020  Acoyte    A  8:00   8.0       16.0
# 2  3/1/2020  Acoyte    A  8:15   8.0       22.0
# 3  3/1/2020  Acoyte    A  8:30   8.0       27.0
# 4  3/1/2020  Acoyte    A  8:45   8.0       37.0

# %%
len(df["station"])
# Out:
# 497579

# %%
import numpy as np

len(np.unique(df["station"]))
# Out:
# 89

# %%
columns = ["line", "pax_TOTAL"]
order = [True, False]

df_sort = df.sort_values(by = columns, ascending = order)
df_sort.head()
# Out:
#            date      station line   from  hour  pax_TOTAL
# 38627  3/7/2020  San Pedrito    A  13:15  13.0      599.0
# 38626  3/7/2020  San Pedrito    A  13:00  13.0      514.0
# 38628  3/7/2020  San Pedrito    A  13:30  13.0      490.0
# 38629  3/7/2020  San Pedrito    A  13:45  13.0      481.0
# 38625  3/7/2020  San Pedrito    A  12:45  12.0      464.0

# %%
line = 'E'
df_filter_line = df[df["line"] == line]

df_filter_line.head()
# Out:
#           date           station line  from  hour  pax_TOTAL
# 3325  3/1/2020  Avenida La Plata    E  7:45   7.0        3.0
# 3326  3/1/2020  Avenida La Plata    E  8:00   8.0        5.0
# 3327  3/1/2020  Avenida La Plata    E  8:15   8.0        8.0
# 3328  3/1/2020  Avenida La Plata    E  8:30   8.0       11.0
# 3329  3/1/2020  Avenida La Plata    E  8:45   8.0       14.0

# %%
len(df_filter_line)
# Out:
# 61622

# %%
df_sliced = df_filter_line.iloc[0:500]

len(df_sliced)
# Out:
# 500

# %%
df_sliced['hour'].hist(bins = 40)
# Out:
# <Axes: >

# %%
df_filter_pm = df_sliced[(df_sliced['hour'] >= 16) & (df_sliced['hour'] <= 18)]
len(df_filter_pm)
# Out:
# 96
